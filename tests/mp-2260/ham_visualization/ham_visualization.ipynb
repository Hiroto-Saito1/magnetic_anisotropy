# %%
import numpy as np 
import matplotlib.pylab  as plt
from pathlib import Path
import sys
import os

src_path = os.path.abspath(os.path.join('..', '..', '..', 'src'))
sys.path.append(src_path)
from mag_rotation import MagRotation

# %%
tb_dat = Path("../pwscf_rel_sym/mae/wan/pwscf_py_tb.dat")
ham = MagRotation(tb_dat=tb_dat, extract_only_x_component=False)

# %%
hopping = ham.spinor_to_vector(ham.reshape_hrs_to_ham_spinor(ham.hopping)[ham.ir0])
mag = ham.spinor_to_vector(ham.reshape_hrs_to_ham_spinor(ham.mag_orig)[ham.ir0])
soc = ham.spinor_to_vector(ham.reshape_hrs_to_ham_spinor(ham.soc)[ham.ir0])

# %%
fontsize = 25
plt.imshow(hopping[0].real)
cbar = plt.colorbar()
cbar.ax.tick_params(labelsize=fontsize)
cbar.set_label("eV", fontsize=fontsize)

ticks = [0,1,4, 9,10,13]
labels = ["$4s$","$4p$","$3d$", "$6s$","$6p$","$5d$"]
plt.xticks(ticks, labels, fontsize=20, rotation=90)
plt.text(0, 21, 'Fe', ha='center', va='center', fontsize=fontsize)
plt.text(9, 21, 'Pt', ha='center', va='center', fontsize=fontsize)
plt.yticks(ticks, labels, fontsize=20)
plt.text(-4.5, 0, 'Fe', ha='center', va='center', fontsize=fontsize)
plt.text(-4.5, 9, 'Pt', ha='center', va='center', fontsize=fontsize)
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.2)
plt.savefig("t.pdf")
plt.show()

# %%
fontsize = 25
plt.imshow(mag[1].real)
cbar = plt.colorbar()
cbar.ax.tick_params(labelsize=fontsize)
cbar.set_label("eV", fontsize=fontsize)

ticks = [0,1,4, 9,10,13]
labels = ["$4s$","$4p$","$3d$", "$6s$","$6p$","$5d$"]
plt.xticks(ticks, labels, fontsize=20, rotation=90)
plt.text(0, 21, 'Fe', ha='center', va='center', fontsize=fontsize)
plt.text(9, 21, 'Pt', ha='center', va='center', fontsize=fontsize)
plt.yticks(ticks, labels, fontsize=20,)
plt.text(-4.5, 0, 'Fe', ha='center', va='center', fontsize=fontsize)
plt.text(-4.5, 9, 'Pt', ha='center', va='center', fontsize=fontsize)
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.2)
plt.savefig("mag_z.pdf")
plt.show()

# %%
fontsize = 25
plt.imshow(soc[3].imag)
cbar = plt.colorbar()
cbar.ax.tick_params(labelsize=fontsize)
cbar.set_label("eV", fontsize=fontsize)

ticks = [0,1,4, 9,10,13]
labels = ["$4s$","$4p$","$3d$", "$6s$","$6p$","$5d$"]
plt.xticks(ticks, labels, fontsize=20, rotation=90)
plt.text(0, 21, 'Fe', ha='center', va='center', fontsize=fontsize)
plt.text(9, 21, 'Pt', ha='center', va='center', fontsize=fontsize)
plt.yticks(ticks, labels, fontsize=20)
plt.text(-4.5, 0, 'Fe', ha='center', va='center', fontsize=fontsize)
plt.text(-4.5, 9, 'Pt', ha='center', va='center', fontsize=fontsize)
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.2)
plt.savefig("lam_z.pdf")
plt.show()
